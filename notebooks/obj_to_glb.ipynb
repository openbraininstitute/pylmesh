# %% [markdown]
# # OBJ to GLB Conversion with pylmesh
#
# This notebook demonstrates how to load OBJ mesh files and export them as GLB (binary GLTF) format.

# %% [markdown]
# ## Install pylmesh
#
# If not already installed:

# %%
# Uncomment to install
# !pip install pylmesh

# %% [markdown]
# ## Import Library

# %%
import pylmesh
import os

print(f"pylmesh version: {pylmesh.__version__}")
# Out:
# pylmesh version: 0.0.9

# %% [markdown]
# ## Load OBJ File

# %%
# Load an OBJ file
obj_file = "../data/meshes/sphere.obj"  # Change to your OBJ file path
if not os.path.exists(obj_file):
    raise FileNotFoundError(f"OBJ file not found: {obj_file}")
mesh = pylmesh.load_mesh(obj_file)

print(f"Loaded: {obj_file}")
print(f"Vertices: {mesh.vertex_count()}")
print(f"Faces: {mesh.face_count()}")
# Out:
# Loaded: ../data/meshes/sphere.obj
# Vertices: 1752
# Faces: 3500

# %% [markdown]
# ## Inspect Mesh Data

# %%
# Show first few vertices
print("First 5 vertices:")
for i, v in enumerate(mesh.vertices[:5]):
    print(f"  v{i}: ({v.x:.3f}, {v.y:.3f}, {v.z:.3f})")

# Show first few faces
print(f"\nFirst 3 faces:")
for i in range(min(3, mesh.face_count())):
    print(f"  f{i}: {mesh.get_face_indices(i)}")
# Out:
# First 5 vertices:
#   v0: (-0.906, -0.115, 0.311)
#   v1: (-0.916, -0.050, 0.328)
#   v2: (-0.905, -0.214, 0.214)
#   v3: (-0.914, -0.149, 0.249)
#   v4: (-0.939, -0.050, 0.250)
#
# First 3 faces:
#   f0: [4, 0, 1]
#   f1: [7, 2, 3]
#   f2: [7, 4, 8]

# %% [markdown]
# ## Export to GLB

# %%
# Export to GLB format
glb_file = "../data/meshes/sphere_exported.glb"

pylmesh.save_mesh(glb_file, mesh)

print(f"Exported to: {glb_file}")
print(f"File size: {os.path.getsize(glb_file) / 1024:.2f} KB")
# Out:
# Exported to: ../data/meshes/sphere_exported.glb
# File size: 7.89 KB

# %% [markdown]
# ## Verify GLB Export

# %%
# Load the exported GLB to verify
mesh_glb = pylmesh.load_mesh(glb_file)

print(f"Verified GLB file:")
print(f"Vertices: {mesh_glb.vertex_count()}")
print(f"Faces: {mesh_glb.face_count()}")
print(f"\nConversion successful! ✓")
# Out:
# Verified GLB file:
# Vertices: 1752
# Faces: 3500
#
# Conversion successful! ✓

# %% [markdown]
# ## Batch Conversion
#
# Convert multiple OBJ files to GLB:

# %% [markdown]
# ## Export to Other Formats
#
# pylmesh supports multiple formats:

# %%
# Export to different formats
formats = [
    ("output.stl", "STL"),
    ("output.ply", "PLY"),
    ("output.off", "OFF"),
    ("output.gltf", "GLTF"),
    ("output.glb", "GLB")
]

for filename, format_name in formats:
    pylmesh.save_mesh(filename, mesh)
    size = os.path.getsize(filename) / 1024
    print(f"✓ {format_name:6} -> {filename:15} ({size:.2f} KB)")
# Out:
# ✓ STL    -> output.stl      (597.96 KB)
# ✓ PLY    -> output.ply      (95.79 KB)
# ✓ OFF    -> output.off      (95.65 KB)
# ✓ GLTF   -> output.gltf     (83.14 KB)
# ✓ GLB    -> output.glb      (7.89 KB)
